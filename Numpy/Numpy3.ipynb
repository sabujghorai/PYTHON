# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# data_structure : [Restaurent_Id , 2021 , 2022 , 2023 , 2024]
import numpy as np
sales_data =np.array([

# [Restaurent :Id , 2021 ,  2022 ,  2023 ,  2024]
            [  1, 150000, 180000, 220000, 250000], # Paradise Biriyani
            [  2, 120000, 140000, 160000, 190000], # Pizza Hub
            [  3, 200000, 230000, 260000, 300000], # Burger Point 
            [  4, 180000, 210000, 240000, 270000], # Chai Point
            [  5, 160000, 185000, 200000, 230000], # Coffe House

])
print("==== Zomato sales Analysis ==== ")
print("\n Sales Data shape :",sales_data.shape) # prints the number of row and column
print("Sample data for 1st 3 rows : \n",sales_data[:,1:]) # Take all rows Skip column 0 (Restaurant ID) Return columns

# Print the sum of the sales
print(f" \n sum of rows : {sales_data[:,1:].sum(axis=1)}") # prints the row elements
print(f" \n sum of columns : {sales_data[:, 1:].sum(axis=0)}") # Prints the columns

# [:, 1:] First : means take all the rows secnd 1: means start from column index 1
# Out:
# ==== Zomato sales Analysis ====
#
#  Sales Data shape : (5, 5)
# Sample data for 1st 3 rows :
#  [[150000 180000 220000 250000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 200000 230000]]
#
#  sum of rows : [800000 610000 990000 900000 775000]
#
#  sum of columns : [ 810000  945000 1080000 1240000]

# %% [markdown]
# ## Minumym sales per restaurent

# %%
import numpy as np
sales_data =np.array([
# [Restaurent :Id , 2021 ,  2022 ,  2023 ,  2024]
            [  1, 150000, 180000, 220000, 250000], # Paradise Biriyani
            [  2, 120000, 140000, 160000, 190000], # Pizza Hub
            [  3, 200000, 230000, 260000, 300000], # Burger Point 
            [  4, 180000, 210000, 240000, 270000], # Chai house
            [  5, 160000, 185000, 200000, 230000], # Coffe House

])

yearly_total = sales_data[:, 1:].sum(axis=0)
print(f"Total income in a year of each shop is is : {yearly_total}")

# minimum sales per restaurent
min_sales = sales_data[:, 1:].min(axis=1) # axis 1 means in a row which is the minimun earning
print(min_sales)

# maximum sales per restaurent
maximum_sales = sales_data[:, 1:].max(axis=0) # axis 0 means in a column which is the max earning
print(f"Maximum earning of the restaurent : {maximum_sales}")

# Average sales per restauresnt
avg_sales = sales_data[:, 1:].mean(axis=0) # average of the column
print(f"Average earning per year : {avg_sales}")
# Out:
# Total income in a year of each shop is is : [ 810000  945000 1080000 1240000]
# [150000 120000 200000 180000 160000]
# Maximum earning of the restaurent : [200000 230000 260000 300000]
# Average earning per year : [162000. 189000. 216000. 248000.]

# %%
import numpy as np
import matplotlib.pyplot as plt
sales_data =np.array([
# [Restaurent :Id , 2021 ,  2022 ,  2023 ,  2024]
            [  1, 150000, 180000, 220000, 250000], # Paradise Biriyani
            [  2, 120000, 140000, 160000, 190000], # Pizza Hub
            [  3, 200000, 230000, 260000, 300000], # Burger Point 
            [  4, 180000, 210000, 240000, 270000], # Chai house
            [  5, 160000, 185000, 200000, 230000], # Coffe House

])

cumilative_sum = np.cumsum(sales_data[:, 1:],axis=1)
print(cumilative_sum)
plt.figure(figsize=(10,6))
plt.plot(np.mean(cumilative_sum,axis=0))
plt.title("Average cumelative sales per year ")
plt.xlabel("Years   ---->")
plt.ylabel("Sales   ---->")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 545000 775000]]

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("\n Matrix addition :", vector1 + vector2)
print("\n Matrix Multiplication :", vector1 * vector2)

print("\n Dot Product :", np.dot(vector1,vector2))
# print("\n Dot Product :", np.cross(vector1,vector2))
angle = np.arccos(
    np.dot(vector1,vector2) / 
    (np.linalg.norm(vector1) * np.linalg.norm(vector2))
)

degree  = np.degrees(angle)
print("Angle :",angle)
print("Degree :", degree )
# Out:
#  Matrix addition : [ 7  9 11 13 15]
#
#  Matrix Multiplication : [ 6 14 24 36 50]
#
#  Dot Product : 130
# Angle : 0.26554161733900966
# Degree : 15.214413958603176

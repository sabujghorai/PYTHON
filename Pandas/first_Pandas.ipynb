# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name" : ["Sabuj","Ram","Subham"],
    "Marks" : [99,68,87],
    "city" : ['kolkata','Naipur','Egra',]
}

df = pd.DataFrame(dict)
print(df)
# Out:
#      name  Marks     city
# 0   Sabuj     99  kolkata
# 1     Ram     68   Naipur
# 2  Subham     87     Egra
